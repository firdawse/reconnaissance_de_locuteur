# %%
import pandas as pd

# %%
def verify_max_score(df):
    # Find the index of the maximum score
    max_score_index = df['Score'].idxmax()

    # Get the Recording Name and Model Name of the observation with the maximum score
    max_score_recording = df.loc[max_score_index, 'Recording Name']
    max_score_model = df.loc[max_score_index, 'Model Name']

    # Verify if the Recording Name and Model Name start with the same first 2 characters
    same_start = max_score_recording[:2] == max_score_model[:2]

    return same_start

# %%
def calculErrorF(df,sec):
    errors = []
    for j in range(11):
        #print(j)
        for k in range(int(60/sec)):
            if(j!=9):
                extracted_df = df[df['Recording Name'] == 'F'+str(j+1)+'.'+str(sec)+'.'+str(k+1)] 
                extracted_df = extracted_df.reset_index(drop=True)
                verify_max_score(extracted_df)
                errors.append(verify_max_score(extracted_df))
    return errors.count(False) / len(errors)

# %%
def calculError(df,sec):
    errors = []
    for j in range(9):
        #print(j)
        for k in range(int(60/sec)):
            if(j!=2):
                extracted_df = df[df['Recording Name'] == 'H'+str(j+1)+'.'+str(sec)+'.'+str(k+1)] 
                extracted_df = extracted_df.reset_index(drop=True)
                verify_max_score(extracted_df)
                errors.append(verify_max_score(extracted_df))
    return errors.count(False) / len(errors)

# %% [markdown]
# ### femmes

# %%
df3F = pd.read_csv('score128F/df.3s.f.128.csv')
err3 = calculErrorF(df3F,3)
err3
# Out:
# 0.025

# %%
df10F = pd.read_csv('score128F/df.10s.f.128.csv')
err10 = calculErrorF(df10F,10)
err10
# Out:
# 0.03333333333333333

# %%
df15F = pd.read_csv('score128F/df.15s.f.128.csv')
err15 = calculErrorF(df15F,15)
err15
# Out:
# 0.025

# %%
df30F = pd.read_csv('score128F/df.30s.f.128.csv')
err30 = calculErrorF(df30F,30)
err30
# Out:
# 0.0

# %%
import matplotlib.pyplot as plt

# Assuming you have a list of errors for each segment length
errors = [err3, err10, err15, err30]

# List of segment lengths
segments = [3, 10, 15, 30]

# Plotting the histogram of errors
plt.bar(segments, errors)

# Adding labels and title
plt.xlabel("Segment Length (s)")
plt.ylabel("Frequency")
plt.title("Histogram of Errors for Different Segment Lengths with gmm128")

# Adding a line connecting the histograms
plt.plot(segments, errors, marker='o', linestyle='--', color='red', label='Line Connecting Histograms')

# Display the plot
plt.legend()
plt.show()

# %%
errors_gmm1024 = [0.2, 0.16666666666666666, 0.1875, 0.1875]
errors_gmm1024
# Out:
# [0.2, 0.16666666666666666, 0.1875, 0.1875]

# %%
errors_gmm128= [err3, err10, err15, err30]
errors_gmm128
# Out:
# [0.025, 0.03333333333333333, 0.025, 0.0]

# %%
errors_gmm512 =[0.015, 0.0, 0.0, 0.0]
errors_gmm512
# Out:
# [0.015, 0.0, 0.0, 0.0]

# %%
errors_gmm256 = [0.015, 0.0, 0.025, 0.0]
errors_gmm256
# Out:
# [0.015, 0.0, 0.025, 0.0]

# %%
import matplotlib.pyplot as plt

# Assuming you have a list of errors for each segment length for gmm128

segments = [3, 10, 15, 30]



# Calculate the width of each bar
bar_width = 1.5

# Calculate the x positions for the bars
segments_gmm128 = [x - 1.5*bar_width for x in segments]
segments_gmm1024 = [x - 0.5*bar_width for x in segments]
segments_gmm512 = [x + 0.5*bar_width for x in segments]
segments_gmm256 = [x + 1.5*bar_width for x in segments]

# Plotting the histogram of errors for gmm128
plt.bar(segments_gmm128, errors_gmm128, width=bar_width, label='gmm128')

# Plotting the histogram of errors for gmm256
plt.bar(segments_gmm256, errors_gmm256, width=bar_width, label='gmm256')

# Plotting the histogram of errors for gmm512
plt.bar(segments_gmm512, errors_gmm512, width=bar_width, label='gmm512')

# Plotting the histogram of errors for gmm1024
plt.bar(segments_gmm1024, errors_gmm1024, width=bar_width, label='gmm1024')



# Adding labels and title
plt.xlabel("Segment Length (s)")
plt.ylabel("Frequency")
plt.title("Histogram of Errors for Different Segment Lengths WOMEN")

# Display the plot
plt.legend()
plt.show()

# %% [markdown]
# ### hommes

# %%
df3 = pd.read_csv('score128H/df.3s.128.csv')
err3 = calculError(df3,3)
err3
# Out:
# 0.0

# %%
df10 = pd.read_csv('score128H/df.10s.128.csv')
err10 = calculError(df10,10)
err10
# Out:
# 0.0

# %%
df15 = pd.read_csv('score128H/df.15s.128.csv')
err15 = calculError(df15,15)
err15
# Out:
# 0.0

# %%
df30 = pd.read_csv('score128H/df.30s.128.csv')
err30 = calculError(df30,30)
err30
# Out:
# 0.0

# %%
errors_gmm128_h =[err3, err10, err15, err30]
errors_gmm128_h
# Out:
# [0.0, 0.0, 0.0, 0.0]

# %%
errors_gmm256_h =[0.0, 0.0, 0.0, 0.0]
errors_gmm256_h
# Out:
# [0.0, 0.0, 0.0, 0.0]

# %%
errors_gmm1024_h = [0.2, 0.16666666666666666, 0.1875, 0.1875]
errors_gmm1024_h
# Out:
# [0.2, 0.16666666666666666, 0.1875, 0.1875]

# %%
errors_gmm512_h = [0.01875, 0.020833333333333332, 0.0, 0.0]
errors_gmm512_h
# Out:
# [0.01875, 0.020833333333333332, 0.0, 0.0]

# %%
import matplotlib.pyplot as plt

# Assuming you have a list of errors for each segment length
errors = errors_gmm128_h

# List of segment lengths
segments = [3, 10, 15, 30]

# Plotting the histogram of errors
plt.bar(segments, errors)

# Adding labels and title
plt.xlabel("Segment Length (s)")
plt.ylabel("Frequency")
plt.title("Histogram of Errors for Different Segment Lengths with gmm128")

# Adding a line connecting the histograms
plt.plot(segments, errors, marker='o', linestyle='--', color='red', label='Line Connecting Histograms')

# Display the plot
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt

# Assuming you have a list of errors for each segment length for gmm128

segments = [3, 10, 15, 30]



# Calculate the width of each bar
bar_width = 1.5

# Calculate the x positions for the bars
segments_gmm128 = [x - 1.5*bar_width for x in segments]
segments_gmm1024 = [x - 0.5*bar_width for x in segments]
segments_gmm512 = [x + 0.5*bar_width for x in segments]
segments_gmm256 = [x + 1.5*bar_width for x in segments]

# Plotting the histogram of errors for gmm128
plt.bar(segments_gmm128, errors_gmm128_h, width=bar_width, label='gmm128')

# Plotting the histogram of errors for gmm256
plt.bar(segments_gmm256, errors_gmm256_h, width=bar_width, label='gmm256')

# Plotting the histogram of errors for gmm512
plt.bar(segments_gmm512, errors_gmm512_h, width=bar_width, label='gmm512')

# Plotting the histogram of errors for gmm1024
plt.bar(segments_gmm1024, errors_gmm1024_h, width=bar_width, label='gmm1024')



# Adding labels and title
plt.xlabel("Segment Length (s)")
plt.ylabel("Frequency")
plt.title("Histogram of Errors for Different Segment Lengths Men")

# Display the plot
plt.legend()
plt.show()
